# %% [markdown]
# <a href="https://colab.research.google.com/github/24tq1a6677-kola/youtube-sentiment-dashboard/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
a=([20,30,40])
var=pd.Series(a,index=["x","y","z"])
print(var)
# Out:
# x    20
# y    30
# z    40
# dtype: int64

# %%
import pandas as pd
car={
    "type":"deisel",
    "color":"black",
    "model":"BMW"
}
var=pd.Series(car)
print(var)
# Out:
# type     deisel
# color     black
# model       BMW
# dtype: object

# %%
df = pd.read_csv('customers-100.csv')

# %%
df.size
# Out:
# 1200

# %%
print('Summary statistics for numerical columns:')
display(df.describe())
# Out:
# Summary statistics for numerical columns:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
print('\nDataFrame information (data types, non-null values):')
df.info()
# Out:
# DataFrame information (data types, non-null values):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
print('\n,the size of this file is ')
display(df.size)
# Out:
# ,the size of this file is
# 1200

# %%
df.shape
# Out:
# (100, 12)

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#         'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#         'Website'],
#        dtype='object')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
df=df.set_index('First Name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %% [markdown]
# ### Original DataFrame (`df`): Notice the 'First Name' is a regular column and the index is a default numerical range.

# %%
display(df.head())

# %% [markdown]
# ### Indexed DataFrame (`df_indexed`): Now 'First Name' is the index, and it's no longer present as a regular column.

# %%
display(df.head())
# Out:
#             Index      Customer Id Last Name                          Company  \
# First Name
# Sheryl          1  DD37Cf93aecA6Dc    Baxter                  Rasmussen Group
# Preston         2  1Ef7b82A4CAAD10    Lozano                      Vega-Gentry
# Roy             3  6F94879bDAfE5a6     Berry                    Murillo-Perry
# Linda           4  5Cef8BFA16c5e3c     Olsen  Dominguez, Mcmillan and Donovan
# Joanna          5  053d585Ab6b3159    Bender         Martin, Lang and Andrade
#
#                          City                     Country  \
# First Name
# Sheryl           East Leonard                       Chile
# Preston     East Jimmychester                    Djibouti
# Roy             Isabelborough         Antigua and Barbuda
# Linda              Bensonview          Dominican Republic
# Joanna         West Priscilla  Slovakia (Slovak Republic)
#
#                            Phone 1                Phone 2  \
# First Name
# ...

# %%
import pandas as pd
df.head()
# Out:
#             Index      Customer Id Last Name                          Company  \
# First Name
# Sheryl          1  DD37Cf93aecA6Dc    Baxter                  Rasmussen Group
# Preston         2  1Ef7b82A4CAAD10    Lozano                      Vega-Gentry
# Roy             3  6F94879bDAfE5a6     Berry                    Murillo-Perry
# Linda           4  5Cef8BFA16c5e3c     Olsen  Dominguez, Mcmillan and Donovan
# Joanna          5  053d585Ab6b3159    Bender         Martin, Lang and Andrade
#
#                          City                     Country  \
# First Name
# Sheryl           East Leonard                       Chile
# Preston     East Jimmychester                    Djibouti
# Roy             Isabelborough         Antigua and Barbuda
# Linda              Bensonview          Dominican Republic
# Joanna         West Priscilla  Slovakia (Slovak Republic)
#
#                            Phone 1                Phone 2  \
# First Name
# ...

# %%
df[df['City']=='East Leonard']
# Out:
#             Index      Customer Id Last Name          Company          City  \
# First Name
# Sheryl          1  DD37Cf93aecA6Dc    Baxter  Rasmussen Group  East Leonard
#
#            Country       Phone 1           Phone 2                     Email  \
# First Name
# Sheryl       Chile  229.077.5154  397.884.0519x718  zunigavanessa@smith.info
#
#            Subscription Date                     Website
# First Name
# Sheryl            2020-08-24  http://www.stephenson.com/

# %%
df.tail(10)
# Out:
#             Index      Customer Id Last Name                      Company  \
# First Name
# Nina           91  5ef6d3eefdD43bE    Chavez                Byrd-Campbell
# Shane          92  98b3aeDcC3B9FF3     Foley                   Rocha-Hart
# Collin         93  aAb6AFc7AfD0fF3     Ayers                Lamb-Peterson
# Sherry         94  54B5B5Fe9F1B6C5     Young      Lee, Lucero and Johnson
# Darrell        95  BE91A0bdcA49Bbc   Douglas  Newton, Petersen and Mathis
# Karl           96  cb8E23e48d22Eae     Greer                    Carey LLC
# Lynn           97  CeD220bdAaCfaDf  Atkinson        Ware, Burns and Oneal
# Fred           98  28CDbC0dFe4b1Db    Guerra                Schmitt-Jones
# Yvonne         99  c23d1D9EE8DEB0A    Farmer           Fitzgerald-Harrell
# Clarence      100  2354a0E336A91A1    Haynes           Le, Nash and Cross
#
#                         City          Country                Phone 1  \
# First Name
# ...

# %%
df[df['Country']=='Solomon Islands']
# Out:
#             Index      Customer Id Last Name                  Company  \
# First Name
# Jordan         38  7a1Ee69F4fF4B4D       Gay          Glover and Sons
# Regina         75  D01Af0AF7cBbFeA     Stein             Guzman-Brown
# Sherry         94  54B5B5Fe9F1B6C5     Young  Lee, Lucero and Johnson
# Fred           98  28CDbC0dFe4b1Db    Guerra            Schmitt-Jones
#
#                     City          Country                Phone 1  \
# First Name
# Jordan      South Walter  Solomon Islands             7208417020
# Regina           Raystad  Solomon Islands  001-469-848-0724x4407
# Sherry      Frankchester  Solomon Islands           158-687-1764
# Fred          Ortegaland  Solomon Islands   +1-753-067-8419x7170
#
#                            Phone 2                               Email  \
# First Name
# Jordan                  8035336772  tiffanydavies@harris-mcfarland.org
# Regina      001-085-360-4426x00357           zrosario@rojas-hardin.net
# ...

# %%
f=df[df['Country']=='Solomon Islands']
f.reset_index(inplace=True)
f
# Out:
#   First Name  Index      Customer Id Last Name                  Company  \
# 0     Jordan     38  7a1Ee69F4fF4B4D       Gay          Glover and Sons
# 1     Regina     75  D01Af0AF7cBbFeA     Stein             Guzman-Brown
# 2     Sherry     94  54B5B5Fe9F1B6C5     Young  Lee, Lucero and Johnson
# 3       Fred     98  28CDbC0dFe4b1Db    Guerra            Schmitt-Jones
#
#            City          Country                Phone 1  \
# 0  South Walter  Solomon Islands             7208417020
# 1       Raystad  Solomon Islands  001-469-848-0724x4407
# 2  Frankchester  Solomon Islands           158-687-1764
# 3    Ortegaland  Solomon Islands   +1-753-067-8419x7170
#
#                   Phone 2                               Email  \
# 0              8035336772  tiffanydavies@harris-mcfarland.org
# 1  001-085-360-4426x00357           zrosario@rojas-hardin.net
# 2       (438)375-6207x003         alan79@gates-mclaughlin.com
# 3   +1-632-666-7507x92121                    swagner@kane.org
#
# ...

# %%
import pandas as pd
df=pd.read_csv("unclean_data.csv", encoding='latin1')

# %%
df.shape
# Out:
# (14, 16)

# %%
df.sample(7)
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 1   Pirates of the Caribbean: At World's End?ÿ                     302
# 7                    Avengers: Age of Ultron?ÿ                     635
# 0                                     Avatar?ÿ                     723
# 10        Batman v Superman: Dawn of Justice?ÿ                     673
# 4                                John Carter?ÿ                     462
# 2                                    Spectre?ÿ                     602
# 9     Harry Potter and the Half-Blood Prince?ÿ                     375
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 1        NaN                     563                    1000
# 7      141.0                      10                   19000
# 0      178.0                      10                     855
# 10     183.0                     NaN                    2000
# 4      132.0                   "475"                     530
# ...

# %%
df.columns=df.columns.str.strip().str.title().str.replace("_"," ")

# %%
print(df.columns)
# Out:
# Index(['Movie Title', 'Num Critic For Reviews', 'Duration',
#        'Director Facebook Likes', 'Actor 3 Facebook Likes',
#        'Actor 1 Facebook Likes', 'Gross', 'Num Voted Users',
#        'Cast Total Facebook Likes', 'Facenumber In Poster',
#        'Num User For Reviews', 'Budget', 'Title Year',
#        'Actor 2 Facebook Likes', 'Imdb Score', 'Title Year.1'],
#       dtype='object')

# %%
print("before:",len(df))
df=df.drop_duplicates()
print("after:",len(df))
# Out:
# before: 14
# after: 14

# %%
df
# Out:
#                                      Movie Title  Num Critic For Reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.isnull().sum()
# Out:
# Movie Title                  0
# Num Critic For Reviews       0
# Duration                     3
# Director Facebook Likes      2
# Actor 3 Facebook Likes       0
# Actor 1 Facebook Likes       0
# Gross                        0
# Num Voted Users              1
# Cast Total Facebook Likes    2
# Facenumber In Poster         5
# Num User For Reviews         0
# Budget                       0
# Title Year                   0
# Actor 2 Facebook Likes       1
# Imdb Score                   0
# Title Year.1                 7
# dtype: int64

# %%
df.fillna(df['Facenumber In Poster'].mean(),inplace=True)
df
# Out:
#                                      Movie Title  Num Critic For Reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.isnull().sum()
# Out:
# Movie Title                  0
# Num Critic For Reviews       0
# Duration                     0
# Director Facebook Likes      0
# Actor 3 Facebook Likes       0
# Actor 1 Facebook Likes       0
# Gross                        0
# Num Voted Users              0
# Cast Total Facebook Likes    0
# Facenumber In Poster         0
# Num User For Reviews         0
# Budget                       0
# Title Year                   0
# Actor 2 Facebook Likes       0
# Imdb Score                   0
# Title Year.1                 0
# dtype: int64
